# %% [markdown]
# ![](https://media.takealot.com/takealot/covers_isbn/9781119002253-pdpxl.jpg)

# %% [markdown]
# * <h1><center>  Storytelling with data </center></h1>

# %% [markdown]
# [Storytelling with data](https://www.amazon.com/Storytelling-Data-Visualization-Business-Professionals/dp/1119002257) is a great book when it comes to the subject of data visualization for storytelling. It is a must read for anyone doing any sort of data analytics. It explains the cognitive considerations behind all the data visualization best practices.
#
# In this notebook, we shall go through some sections of the book, starting with consideration of the context (target audience, objective), choosing an appropriate chart format, eliminating clutter...my overall favourite discussion from the book, focusing the viewer on key elements, and other design considerations.
#
# **NB:** The examples within the book are done in excel, so in this notebook we shall seek to reproduce the graphs in Python. For those interested in the excel files...see [Knaflic, Cole. Storytelling With Data: A Data Visualization Guide for Business Professionals, Wiley, © 2015.](http://www.storytellingwithdata.com/book/downloads)

# %% [markdown]
# ![](https://www.cision.com/content/dam/cision/blogs/july-2018/Data-Backed%20Storytelling.png)

# %% [markdown]
# In most cases, analytics requires us to be in the **exploratory** phase...which is what one does to understand and figure out what might be noteworthy or interesting to highlight to others. However, presenting the results from our EDA, requires us to be in the **explanatory** phase, implying you have a specific thing that you want to explain to your target audience...**a specific story you want to tell**.
#
# Ideally we would like to be able to turn the data into information that can be consumed by an audience with relative ease.
#
# Let's do this!!

# %%
## Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns;sns.set_style()

# %% [markdown]
# # Understanding the importance of context

# %% [markdown]
# Success in data visualization does not start with data visualization. Rather, before you begin down the path of creating a data visualization or communication, attention and time should be paid to understanding the context for the need to communicate.

# %% [markdown]
# ## Who, what, and how

# %% [markdown]
# Once the need to communicate is deemed necessary, the are then three steps one should think about and be clear on before visualizing any data:
#
# * <font color=blue>Who</font>
#     * Your audience
#     The more specific you can be about who your audience is, the better position you will be in for succesful communication. The more you know about your audience, the better position you'l be to understand how best to resonate with them
#     * You
#     The relationship that you have with the audience also matters and how you expect that they will perceive you? Do they already trust you as an expert or do you need to work to establish credibility?
# * <font color=blue>What</font>
#     * Action
#     What do you need your audience to know or do?. If you simply present data, it's easy for the audience to say "Oh, that's interesting" and move on to the next thing. But if you ask for action, your audience has to make a decision to comply or not. When it really isn't appropriate to to recommend an action explicitly, encourage discussion towards one.
#
# * <font color=blue>How</font>
#     * Once, we have articulated who our audience is and what we need them to know or do - we can turn to the data. Data becomes supporting evidence of the story you will build and tell.
#
# * Storyboarding
#     * Creating a visual outline of the content you plan to create, can also help in ensuring that the communication you craft is on point.

# %% [markdown]
# ## Background of the data:

# %% [markdown]
# Call logging within IT department of company X
#
# In the past year, the IT department has let a couple of people go. The remaining employees had to "pick up the slack". The hiring manager would like to understand what impact the departure of the individuals has had over the past year. He/she then plots the monthly volume of calls logged and resolved over the past calendar year.
# From the plot he/she sees some evidence of the teams productivity suffering from being short-staffed and now wants to turn this quick-and-dirty visual into a story to support his/her hiring request.
#
# This data is taken from [Knaflic, Cole. Storytelling With Data: A Data Visualization Guide for Business Professionals, Wiley, © 2015.](http://www.storytellingwithdata.com/book/downloads), with the main story given a slight twist as compared to the one in the book.

# %%
df2 = pd.DataFrame({'Month':['January','February','March','April','May','June','July','August','September','October','November','December'],
                   'Ticket_Volume_Received':[160,184,241,149,180,161,132,202,160,139,149,177],
                   'Ticket_Volume_Processed':[160,184,237,148,181,150,123,156,126,104,124,140]})
names= ['January','February','March','April','May','June','July','August','September','October','November','December']
names2= ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %% [markdown]
# # Choosing an appropriate display

# %% [markdown]
# ![](https://static1.squarespace.com/static/55b6a6dce4b089e11621d3ed/t/55dbac72e4b000099dccf405/1440459893535/)

# %% [markdown]
# What is the right graph for my situation? The answer is always the same: Whatever will be easiest for my audience to read.
#
# There are many different types of graphs and visual displays but something to remember is that the fact that you have some numbers does not mean you need a graph. Simple text can be a great way to communicate too. In this section, we look at data from [Knaflic, Cole. Storytelling With Data: A Data Visualization Guide for Business Professionals, Wiley, © 2015.](http://www.storytellingwithdata.com/book/downloads), and have a look at two visual displays of the same data, with the goal of determining which graph is easiest to read...in my opinion at least.

# %% [markdown]
# <font color=blue>The first graph is a stacked bar plot:</font>

# %%
# %matplotlib inline
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.barplot(x=df2.index,y=df2['Ticket_Volume_Received'],data=df2,label = 'Calls Logged',color='#4848FF',ax=ax)
sns.barplot(x=df2.index,y=df2['Ticket_Volume_Processed'],data=df2,label = 'Calls Resolved',color='#FF6800',ax=ax)
plt.title('Monthly Volume of IT calls Logged and Resolved',fontsize=14,ha='right')
# Put a legend below current axis
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08),fancybox=True, shadow=False, ncol=5,fontsize=12)
plt.grid(axis='y')
plt.ylabel('')
plt.ylim(0,300)
ax.set(xticks=range(0, 12), xticklabels=list(names));

# %% [markdown]
# <font color=blue>The second graph of the exact same data but now displayed using a line plot:</font>

# %%
# %matplotlib inline
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.lineplot(x=df2.index,y=df2['Ticket_Volume_Received'],data=df2,marker='o',markersize=10,lw=4,label = 'Calls Logged',color='#4848FF',ax=ax)
sns.lineplot(x=df2.index,y=df2['Ticket_Volume_Processed'],data=df2,marker='s',markersize=10,lw=4,label = 'Calls Resolved',color='#FF6800',ax=ax)
plt.title('Monthly Volume of IT calls Logged and Resolved',fontsize=14,ha='right')
# Put a legend below current axis
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08),fancybox=True, shadow=False, ncol=5,fontsize=12)
plt.grid(axis='y')
plt.ylabel('')
plt.ylim(0,300)
ax.set(xticks=range(0, 12), xticklabels=list(names));

# %% [markdown]
# Soo...which graph is easiest to read?...In my opinion, I would say the line plot, which kinda makes sense, given that we're plotting a time series. In the next section, we shall look at various ways of decluttering the latter.

# %% [markdown]
# # Clutter is your enemy

# %% [markdown]
# Every single element you add to the page or screen takes up cognitive load on the part of your audience. With cognitive load being the mental effort required to learn new information.
#
# What is clutter?
# These are visual elements that take up space but don't increase understanding.
#
# When our visuals feel complicated, we run the risk of our audience deciding that they don't want to take the time to understand what we're showing them, at which point we've lost our ability to communicate with them.
#
# **Gestallt Principles** of visual perception can help you understand how your audience sees:
# * <font color=blue>Proximity</font>
#     * We tend to think of objects that are physically close together as being part of a group
# * <font color=blue>Similarity</font>
#     * Objects that are of similar color, shape, size, or orientation are perceived as related or belonging to part of a group
# * <font color=blue>Enclosure</font>
#     * We think of objects that are physically enclosed together as belonging to part of a group.
# * <font color=blue>Closure</font>
#     * The concept of closure says that people like things to be simple and fit into the constructs that are already in our head e.g. when parts of a whole are missing, our eyes fill in the gaps.
# * <font color=blue>Continuity</font>
#     * The principle of continuity is similar to closure: when looking at objects, our eyes seek the smoothest path and naturally create continuity in what we see even where it may not explicitly exist.
# * <font color=blue>Connection</font>
#     * We tend to think of objects that are physically connected as part of a group.

# %% [markdown]
# ![](https://i.pinimg.com/originals/a6/0d/c3/a60dc33958386baf31ee54f852230524.jpg)

# %% [markdown]
# ## Cluttered figure:

# %% [markdown]
# Here's the line plot we deemed as an appropriate display in this case:

# %%
# %matplotlib inline
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.lineplot(x=df2.index,y=df2['Ticket_Volume_Received'],data=df2,marker='o',markersize=10,lw=4,label = 'Calls Logged',color='#4848FF',ax=ax)
sns.lineplot(x=df2.index,y=df2['Ticket_Volume_Processed'],data=df2,marker='s',markersize=10,lw=4,label = 'Calls Resolved',color='#FF6800',ax=ax)
plt.title('Monthly Volume of IT calls Logged and Resolved',fontsize=14,ha='right')
# Put a legend below current axis
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08),fancybox=True, shadow=False, ncol=5,fontsize=12)
plt.grid(axis='y')
plt.ylabel('')
plt.ylim(0,300)
ax.set(xticks=range(0, 12), xticklabels=list(names));

# %% [markdown]
# Off the bat, we notice that there are a lot of unnecessary visual elements in this graph, examples include, the markers, guiding lines..etc

# %% [markdown]
# ## Decluttered Figure:

# %% [markdown]
# Getting rid of all the clutter...i.e, entirely removing the top and right border, deemphasizing the remaining two by using a grey color to force them into the background, deemphasizing the title, shortening the months to only three letters, and finally using the gestallt principles of proximity and similarity, we get the following graph

# %%
# %matplotlib inline
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.lineplot(df2.index,y=df2['Ticket_Volume_Received'],marker='o',markersize=10,data=df2,lw=4,color='#4848FF',ax=ax)
sns.lineplot(df2.index,y=df2['Ticket_Volume_Processed'],marker='s',markersize=10,data=df2,lw=4,color='#FF6800',ax=ax)
plt.title('Monthly Volume of IT calls Logged and Resolved',fontsize=18,ha='right',color='#616161')
sns.despine()
# Change the colors of the left and bottom borders (fade into the background)
ax.spines['left'].set_color('lightgray')
ax.spines['bottom'].set_color('lightgray')
ax.text(12.6, 180, 'Logged', ha='right', va='top', fontsize=22,color='#4848FF')
ax.text(12.8, 145, 'Resolved', ha='right', va='top', fontsize=22,color='#FF6800')
plt.ylabel('')
plt.ylim(0,300)
ax.set(xticks=range(0, 12), xticklabels=list(names2))
plt.ylabel('Volume',fontsize=16,color='#616161')
fig.text(
        0.05, 0.05,
        'Adapted from: Storytelling with Data by Cole Nussbaumer Knaflic',
        ha='left',fontsize=12);
# Out:
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Removing the markers:

# %%
# %matplotlib inline
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.lineplot(df2.index,y=df2['Ticket_Volume_Received'],data=df2,lw=4,color='#4848FF',ax=ax)
sns.lineplot(df2.index,y=df2['Ticket_Volume_Processed'],data=df2,lw=4,color='#FF6800',ax=ax)
plt.title('Monthly Volume of IT calls Logged and Resolved',fontsize=18,ha='right',color='#616161')
sns.despine()
# Change the colors of the left and bottom borders (fade into the background)
ax.spines['left'].set_color('lightgray')
ax.spines['bottom'].set_color('lightgray')
ax.text(12.6, 180, 'Received', ha='right', va='top', fontsize=22,color='#4848FF')
ax.text(12.8, 145, 'Processed', ha='right', va='top', fontsize=22,color='#FF6800')
plt.ylabel('')
plt.ylim(0,300)
ax.set(xticks=range(0, 12), xticklabels=list(names2))
plt.ylabel('Volume',fontsize=16,color='#616161')
fig.text(
        0.05, 0.05,
        'Adapted from: Storytelling with Data by Cole Nussbaumer Knaflic',
        ha='left',fontsize=12);
# Out:
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Draw attention where you want it

# %% [markdown]
# ## Preattentive attributes

# %% [markdown]
# ![title](http://onemogin.com/assets/images/dash-p2-preattentive.png)

# %% [markdown]
# Preattentive processing takes place in sensory memory; it requires no conscious effort from the user (or viewer) to do this processing - it's automated and takes less than 500 milliseconds to complete. This is helpful in information visualization design, because it allows the designer to grab the attention of the user without their input or effort.
#
# Preattentive attributes can be used to:
# * Help direct your audiences attention to where you want them to focus it.
# * Create a visual hierachy of elements to lead your audience through the information you want to communicate in the way you want them to process it.

# %%
y = [202,160,139,149,177]
x = [7, 8, 9, 10, 11]
n = [202,160,139,149,177]

y1 = [156,126,104,124,140]
x1 = [7, 8, 9, 10, 11]
n1 = [156,126,104,124,140]

# %matplotlib inline

markers_on = [202,160,139,149,177]
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.lineplot(df2.index,y=df2['Ticket_Volume_Received'],data=df2,lw=4,color='#808080',ax=ax)
sns.lineplot(df2.index,y=df2['Ticket_Volume_Processed'],data=df2,lw=4,color='#000088',ax=ax)
sns.lineplot(x,y,marker='o',markersize=10,color='#808080',ax=ax)
sns.lineplot(x1,y1,marker='o',markersize=10,color='#000088',ax=ax)
#plt.title('Monthly Volume Received and Processed, as of Dec 2011',fontsize=18,ha='right',color='#616161')
sns.despine()
# Change the colors of the left and bottom borders (fade into the background)
ax.spines['left'].set_color('lightgray')
ax.spines['bottom'].set_color('lightgray')
ax.text(12.6, 180, 'Received', ha='right', va='top', fontsize=20,color='#808080')
ax.text(12.8, 145, 'Processed', ha='right', va='top', fontsize=20,color='#000088')
plt.ylabel('')
plt.ylim(0,300)
ax.set(xticks=range(0, 12), xticklabels=list(names2))
plt.ylabel('Volume',fontsize=16,color='#616161')

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]),fontsize=16)
    

for i, txt in enumerate(n1):
    ax.annotate(txt, (x1[i], y1[i]),fontsize=16)
fig.text(
        0.05, 0.05,
        'Adapted from: Storytelling with Data by Cole Nussbaumer Knaflic',
        ha='left',fontsize=12)
# Out:
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# In the graph above, **attention is drawn to the fact that the difference between the Received and Processed volume started to differ significantly around August**. By understanding, how our audience sees and processes information, we put ourselves in a better position to be able to communicate effectively.

# %% [markdown]
# # Think like a designer

# %% [markdown]
# According to [Knaflic, Cole. Storytelling With Data: A Data Visualization Guide for Business Professionals, Wiley, © 2015.](http://www.storytellingwithdata.com/book/downloads), thinking like a designer involves
#
# * highlighting important stuff
# * eliminating distractions
# * understanding what the audience wants to do with the data (function) and create a visualization (form) that allows for this
# * not overcomplicating, thus making your designs accessible to everyone
# * using text to label, introduce, explain, reinforce, highlight, recommend and ultimately...tell a story
# * and making graphs aesthetically pleasing
#
# **Applying all these principles yields the following graph**:

# %%
y = [202,160,139,149,177]
x = [7, 8, 9, 10, 11]
n = [202,160,139,149,177]

y1 = [156,126,104,124,140]
x1 = [7, 8, 9, 10, 11]
n1 = [156,126,104,124,140]

# %matplotlib inline

markers_on = [202,160,139,149,177]
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
# Variables that define subsets of the data, which will be drawn on separate facets in the grid.
sns.lineplot(df2.index,y=df2['Ticket_Volume_Received'],data=df2,lw=4,color='#808080',ax=ax)
sns.lineplot(df2.index,y=df2['Ticket_Volume_Processed'],data=df2,lw=4,color='#000088',ax=ax)
sns.lineplot(x,y,marker='o',markersize=10,color='#808080',ax=ax)
sns.lineplot(x1,y1,marker='o',markersize=10,color='#000088',ax=ax)
#plt.title('My subtitle',fontsize=16,ha='left',va='top',color='#616161',y=0.85)
plt.suptitle('Please approve the hire of 2 employees',fontsize=24,ha='right',va='top',color='#000088', y=1)
sns.despine()
# Change the colors of the left and bottom borders (fade into the background)
ax.spines['left'].set_color('lightgray')
ax.spines['bottom'].set_color('lightgray')
ax.text(12.6, 180, 'Received', ha='right', va='top', fontsize=20,color='#808080')
ax.text(12.8, 145, 'Processed', ha='right', va='top', fontsize=20,color='#000088')
plt.annotate("2 employees quit in May. We nearly kept up with incoming calls\nin the following two months,\
 but fell behind with the increase in\nAug and haven't been able to catch up since.",
             xy=(4,60),xytext=(4,260),color='#616161',fontsize=18)
plt.ylabel('')
plt.ylim(0,300)
plt.axvline(x=4, ymin=0, ymax=0.85, color='#616161', alpha=0.3)
ax.set(xticks=range(0, 12), xticklabels=list(names2))
plt.ylabel('Number of Calls',fontsize=16,color='#616161',ha='left',va='bottom')

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]),fontsize=16)
    

for i, txt in enumerate(n1):
    ax.annotate(txt, (x1[i], y1[i]),fontsize=16)

fig.text(
        0.05, 0.05,
        'Adapted from: Storytelling with Data by Cole Nussbaumer Knaflic',
        ha='left',fontsize=12)
# Out:
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\a00018578\Documents\projects\advana\mimocko\.venv-mimocko\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# The goal of this notebook, is to give an overview of some of the best data visualization practices I've learned from [Knaflic, Cole. Storytelling With Data: A Data Visualization Guide for Business Professionals, Wiley, © 2015.](http://www.storytellingwithdata.com/book/downloads), and use almost everyday. It is my hope that this rather simple overview helps someone out there...who like me does not enjoy excel that much, tell better stories with their data, using Python.

# %% [markdown]
# # References:

# %% [markdown]
# [Knaflic, Cole. Storytelling With Data: A Data Visualization Guide for Business Professionals, Wiley, © 2015.](http://www.storytellingwithdata.com/book/downloads)
